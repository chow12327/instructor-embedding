# %% [markdown]
# Reproduction of experiments for InstructOR Embeddings on classification of sentences available in the below 2 datasets:
#
# 1. [MTEB Emotion dataset](https://huggingface.co/datasets/mteb/emotion)
# 2. [MTEB MTOP Domain](https://huggingface.co/datasets/mteb/mtop_domain/viewer/en)
#
# Steps to run the experiment:
#
# Step 1: Update parameters in the code cell for [MTEB Emotion classification](https://colab.research.google.com/drive/1jD8kxqu5dSFMvpSsX0N9yTWN9r3e43VM#scrollTo=_XboV6__tm5s&line=1&uniqifier=1) and [MTEB MTOP Domain Classification](https://colab.research.google.com/drive/1jD8kxqu5dSFMvpSsX0N9yTWN9r3e43VM#scrollTo=EiASp0ia44ci&line=2&uniqifier=1).The following parameters can be adjusted:
#
#
# 1. Seed (seed)
# 2. Batch Size (batch_size)
# 3. Training Samples/label for logistic regression (samples_per_label)
# 4. Number of Experiments per dataset (n_experiment)
#
# Step 2: Run all

# %%
# !git clone https://github.com/chow12327/instructor-embedding.git

# %%
# !pip install -r requirements.txt

# %%
# !pip install InstructorEmbedding

# %%
# !pip3 install -e evaluation/MTEB
# !pip3 install checklist

# %% [markdown]
# Robustness and Multilinguality Check on mteb/emotion dataset-
# 1. Base Instructor (HuggingFace model)
# 2. Trained Instructor
# 3. Base use-cmlm-multilingual
# 4. Trained use-cmlm-multilingual

# %%
#provide multiple parameter values here.
models = ['hkunlp/instructor-base']
seeds = [38]
batchsizes = [64]
samplesperlabels = [8]

for model in models:
  for seed in seeds:
    for batch_size in batchsizes:
      for samplesperlabel in samplesperlabels:
        # !python3 evaluation/MTEB/examples/evaluate_model.py --model_name {model} --output_dir outputs --task_name 'EmotionClassification' --result_file results --batch_size {batch_size} --samples_per_label {samplesperlabel}
# Out:
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: hkunlp/instructor-base
# load INSTRUCTOR_Transformer
# max_seq_length  512
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device: cpu
# INFO:mteb.evaluation.MTEB:
#
# ## Evaluating 1 tasks:
# ─────────────────────────────── Selected tasks  ────────────────────────────────
# Classification
#     - EmotionClassification, s2s
#
#
# INFO:mteb.evaluation.MTEB:
#
# ********************** Evaluating EmotionClassification **********************
# INFO:mteb.evaluation.MTEB:Loading dataset for EmotionClassification
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
#
# Task: EmotionClassification, split: test. Running...
# INFO:mteb.abstasks.AbsTaskClassification:========== Experiment 1/1 ==========
# Seed set at evaluate_model level
# use logRegClassificationEvaluator
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:Encoding 48 training sentences...
# with prompt
# with prompt
# /Users/nidhichowdhry/Documents/GMU/CS 678/Project/checklist/checklist/text_generation.py:171: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:264.)
#   to_pred = torch.tensor(to_pred, device=self.device).to(torch.int64)
# with prompt
# with prompt
# with prompt
# with prompt
# with prompt
# with prompt
# with prompt
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:Encoding 2000 test sentences...
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:Fitting logistic regression classifier...
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:Incorrect vocab sentences
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:[['i feel bad that it got so bad' '0' '3']
#  ['i also feel lethargic .' '0' '4']
#  ['i have been feeling guilty recently that i did not know back then that the abuse was not my fault and that it did not happen because of who i was'
#   '0' '3']
#  ['i was benevolent enough to buy them some candy and other treats' '1'
#   '2']
#  ['i said before do feel free to contact me this is something i am interested in finding out more about'
#   '1' '0']
#  ['i think we need a little romantic comedy in the relationship' '2' '0']
#  ['i feel the loving presence of my parents daily even though they have both been presumed dead for almost years now'
#   '2' '5']
#  ['i could never feel loving toward someone without them ever knowing it if i dont act like it'
#   '2' '1']
#  ['i suddenly feel that this is more than a cheesy love song that every parent could sing in front of their kids'
#   '2' '1']
#  ['i love what i do and i feel so blessed and lucky to be able to travel and be creative and meet amazing people and wake up every day loving my job'
#   '2' '1']
#  ['i feel more violent than ever right now' '3' '4']
#  ['i cannot explain why but i need to say please feel my pain i have heart and im not a heartless person'
#   '3' '5']
#  ['i remained unprotected even while traveling alone' '4' '0']
#  ['i feel a restless wind heading our way' '4' '3']
#  ['a surprise party was planned in advance and her face lit up with excitement as she entered the room'
#   '5' '1']
#  ['hearing the news of a promotion at work was an unexpected surprise that brought a smile to her face'
#   '5' '1']]
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:Incorrect robustness sentences
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:[['i spend a lot of time feeling dissapointed with myself for not doing a better job at raiisng my kids'
#   '0' '3']
#  ['i cannot xeplain why but i need to say please feel my pain i have heart and im not a heartless person'
#   '0' '4']
#  ['i walked near the church and i felt very obvious and uneasy all the warnings about hate crime i read in the guidebook and maybe some ersidual from years ago left me feeling uneasy'
#   '0' '4']
#  ['hearing the news of a promotion at work was an unexpected surprise that brought a smile to her afce'
#   '0' '1']
#  ['i feel more rfustrated and annoyed by their behavior' '0' '3']
#  ['i feel bad that it got os bad' '1' '3']
#  ['i feel a restless wind heading our wya' '1' '5']
#  ['i get frustrated that these issues from my past have had a very negatiev effect on my behavior and feel people must be angry that i have not resolved them by now'
#   '1' '3']
#  ['i often feel confused as to whether i have sin or just a really hard core sinful nautre'
#   '2' '4']
#  ['i can feel the presusre even more so on my shoulders and im feeling slightly unsure of myself which leads to unhappy thoughts not usually like my optimistic self i must say'
#   '2' '4']
#  ['i believe that feleing accepted in a certain way can be empowering'
#   '2' '1']
#  ['i giggle when i write this and shake my head ni humbling disbelief but in a way i feel somewhat relieved'
#   '2' '1']
#  ['i feel more violnet than ever right now' '2' '4']
#  ['i soon realized that an initial reaction to an activity that feels playful is often followed by a desire to practice to perfect the talent that eld to the initial enjoyment'
#   '3' '1']
#  ['i was benevoletn enough to buy them some candy and other treats' '3'
#   '5']
#  ['i said before do feel free to contact me this is something i am interested i nfinding out more about'
#   '3' '0']
#  ["As a present he couldn't hide his surprise when he saw the rare diamond he had alawys wanted"
#   '3' '5']
#  ['a surprise party was planned in advance and her face lit up with excitement as she enetred the room'
#   '3' '1']
#  ['im all cooped up and impatient an dannoyingly annoying' '4' '3']
#  ['i feel the loving presence ofm y parents daily even though they have both been presumed dead for almost years now'
#   '4' '5']
#  ['i have been feeling guilty recently that i did not know back then that the abuse was not my fault and that it did not hpapen because of who i was'
#   '4' '3']
#  ['the unexpected plot twsit in the finale caught the audience off guard leaving them in shock'
#   '4' '5']
#  ['i think we need a little romantic comedy in the relatoinship' '5' '0']
#  ["i can't stop feeling lonel ywhen i am alone and when i've got no friends"
#   '5' '0']
#  ['i could never feel loving toward someone wtihout them ever knowing it if i dont act like it'
#   '5' '0']
#  ['i remained unprotected evne while traveling alone' '5' '0']]
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:Incorrect ner sentences
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:[['i looked at Deborah this morning i named my left breast Deborah my right one is Deborah and i feel this weird mixture of anger and loss Deborah wrote less than a month after her diagnosis'
#   '4' '0']
#  ['i get the impression that Tom was really feeling it but Tom still prefers her beloved Tom Palmer purrrr'
#   '2' '1']
#  ['i get people asking me what it feels like to be the most hated man in Tucson county said assessor Carolyn Jordan'
#   '0' '5']
#  ['i was still feeling weepy and strung out so Charlie treated me to ice cream and a movie a spiderman'
#   '0' '5']]
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:Incorrect Negative sentences
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:[["i didn't look at mabel this morning i named my left breast mabel my right one is hazel and i feel this weird mixture of anger and loss valerie wrote less than a month after her diagnosis"
#   '4' '0']
#  ["i don't get the impression that banjo was really feeling it but molly still prefers her beloved katy perry purrrr"
#   '2' '1']
#  ["i get people asking me what it feels like to be the most hated man in dallas county didn't say assessor steve helm"
#   '0' '5']
#  ['i was still not feeling weepy and strung out so maggie treated me to ice cream and a movie a href http www'
#   '0' '5']
#  ["i don't feel embarrassed that it got so bad" '0' '1']
#  ["i don't spend a lot of time feeling disappointed with myself for not doing a better job at attaining my goals"
#   '0' '4']
#  ["i also don't feel lethargic and again" '0' '1']
#  ["i don't believe that feeling accepted in a non judgemental way can be healing"
#   '1' '4']
#  ["i don't feel benevolent enough to buy them some peanuts and other treats"
#   '1' '0']
#  ["i don't write this i giggle and shake my head in humbling shame but in a way i feel somewhat triumphant"
#   '1' '4']
#  ["i didn't say before do feel free to contact me this is something i am interested in finding out more about"
#   '1' '0']
#  ["i don't get frustrated that unresolved issues from my past have had a severe negative effect on my behavior and feel he must be angry that i have not resolved them by now"
#   '3' '0']
#  ["i don't feel more violent than ever right now" '3' '4']]
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:Incorrect Positive sentences
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:[['i can stop the anxiety i feel when i m alone when i ve got no distractions'
#   '0' '4']
#  ['i can explain why but i need to say please understand my feeling i have heart and im a heartless person'
#   '3' '4']
#  ['i know if this helps at all but writing all of this has made me feel somewhat regretful of ashamed of who i was and while i have more to share i just think i can right now'
#   '0' '4']
#  ['i want them to feel so pressured' '4' '3']
#  ['i have a schedule or childhood friends and feel a little timid about just getting out there by myself'
#   '4' '0']
#  ["i eat a good breakfast i feel more energetic throughout the whole day and feel that o'clock slump"
#   '1' '2']]
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:Robusness Accuracies...
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:Vocab
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:0.4666666666666667
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:Robusness
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:0.13333333333333333
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:NER
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:0.2
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:negative
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:0.1875
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:positive
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:0.4
# ERROR:mteb.evaluation.MTEB:Error while evaluating EmotionClassification: all the input array dimensions except for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 6000 and the array at index 1 has size 2000
# ERROR:mteb.evaluation.MTEB:Please check all the error logs at: error_logs.txt
# Traceback (most recent call last):
#   File "/Users/nidhichowdhry/Documents/GMU/CS 678/Project/instructor-embedding/evaluation/MTEB/examples/evaluate_model.py", line 55, in <module>
#     evaluation.run(model, output_folder=args.output_dir, eval_splits=[args.split],args=args,)
#   File "/Users/nidhichowdhry/Documents/GMU/CS 678/Project/instructor-embedding/evaluation/MTEB/mteb/evaluation/MTEB.py", line 267, in run
#     task_name = list(evaluation_results.keys())[0]
# IndexError: list index out of range

# %%
#provide multiple parameter values here.
models = ['models/outputs_l2e5']
seeds = [38]
batchsizes = [64]
samplesperlabels = [8]

for model in models:
  for seed in seeds:
    for batch_size in batchsizes:
      for samplesperlabel in samplesperlabels:
        # !python3 evaluation/MTEB/examples/evaluate_model.py --model_name {model} --output_dir outputs --task_name 'EmotionClassification' --result_file results --batch_size {batch_size} --samples_per_label {samplesperlabel} --seed {seed} --robustnessSamples 10

# %%
#provide multiple parameter values here.
models = ['sentence-transformers/use-cmlm-multilingual']
seeds = [38]
batchsizes = [32]
samplesperlabels = [8]

for model in models:
  for seed in seeds:
    for batch_size in batchsizes:
      for samplesperlabel in samplesperlabels:
        # !python3 evaluation/MTEB/examples/evaluate_model.py --model_name {model} --output_dir outputs --task_name 'EmotionClassification' --result_file results --batch_size {batch_size} --samples_per_label {samplesperlabel} --n_experiments 1
# Out:
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: sentence-transformers/use-cmlm-multilingual
# load INSTRUCTOR_Transformer
# Some weights of the model checkpoint at /Users/nidhichowdhry/.cache/torch/sentence_transformers/sentence-transformers_use-cmlm-multilingual/ were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# max_seq_length  512
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device: cpu
# INFO:mteb.evaluation.MTEB:
#
# ## Evaluating 1 tasks:
# ─────────────────────────────── Selected tasks  ────────────────────────────────
# Classification
#     - EmotionClassification, s2s
#
#
# INFO:mteb.evaluation.MTEB:
#
# ********************** Evaluating EmotionClassification **********************
# INFO:mteb.evaluation.MTEB:Loading dataset for EmotionClassification
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
#
# Task: EmotionClassification, split: test. Running...
# INFO:mteb.abstasks.AbsTaskClassification:========== Experiment 1/1 ==========
# Seed set at evaluate_model level
# use logRegClassificationEvaluator
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:Encoding 48 training sentences...
# with prompt
# with prompt
# /Users/nidhichowdhry/Documents/GMU/CS 678/Project/checklist/checklist/text_generation.py:171: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:264.)
#   to_pred = torch.tensor(to_pred, device=self.device).to(torch.int64)
# with prompt
# with prompt
# with prompt
# with prompt
# with prompt
# with prompt
# with prompt
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:Encoding 2000 test sentences...
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:Fitting logistic regression classifier...
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:Incorrect vocab sentences
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:[['i feel bad that it got so bad' '0' '3']
#  ['i spend a lot of time feeling dissapointed with myself for not doing a better job at raising my kids'
#   '0' '3']
#  ['i also feel lethargic .' '0' '5']
#  ['i have been feeling guilty recently that i did not know back then that the abuse was not my fault and that it did not happen because of who i was'
#   '0' '3']
#  ['i believe that feeling accepted in a certain way can be empowering'
#   '1' '2']
#  ['i was benevolent enough to buy them some candy and other treats' '1'
#   '3']
#  ['i giggle when i write this and shake my head in humbling disbelief but in a way i feel somewhat relieved'
#   '1' '3']
#  ['i said before do feel free to contact me this is something i am interested in finding out more about'
#   '1' '5']
#  ['i soon realized that an initial reaction to an activity that feels playful is often followed by a desire to practice to perfect the talent that led to the initial enjoyment'
#   '1' '3']
#  ['i think we need a little romantic comedy in the relationship' '2' '3']
#  ['i feel the loving presence of my parents daily even though they have both been presumed dead for almost years now'
#   '2' '5']
#  ['i suddenly feel that this is more than a cheesy love song that every parent could sing in front of their kids'
#   '2' '5']
#  ['i love what i do and i feel so blessed and lucky to be able to travel and be creative and meet amazing people and wake up every day loving my job'
#   '2' '5']
#  ['i cannot explain why but i need to say please feel my pain i have heart and im not a heartless person'
#   '3' '2']
#  ['im all cooped up and impatient and annoyingly annoying' '3' '5']
#  ['i remained unprotected even while traveling alone' '4' '5']
#  ['i often feel confused as to whether i have sin or just a really hard core sinful nature'
#   '4' '3']
#  ['i feel a restless wind heading our way' '4' '5']]
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:Incorrect robustness sentences
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:[['i spend a lot of time feeling dissapointed with myself for not doing a better job at raiisng my kids'
#   '0' '3']
#  ['i cannot xeplain why but i need to say please feel my pain i have heart and im not a heartless person'
#   '0' '2']
#  ['i walked near the church and i felt very obvious and uneasy all the warnings about hate crime i read in the guidebook and maybe some ersidual from years ago left me feeling uneasy'
#   '0' '4']
#  ['hearing the news of a promotion at work was an unexpected surprise that brought a smile to her afce'
#   '0' '5']
#  ['i feel more rfustrated and annoyed by their behavior' '0' '3']
#  ['i feel bad that it got os bad' '1' '3']
#  ['i suddenly feel that this is more than a cheesy love song that every parent could sign in front of their kids'
#   '1' '5']
#  ['i feel a restless wind heading our wya' '1' '2']
#  ['i love what i do and i feel so blessed and lucky to be able to travel and be creative and meet amazing people and wake up every day loving ym job'
#   '1' '5']
#  ['i get frustrated that these issues from my past have had a very negatiev effect on my behavior and feel people must be angry that i have not resolved them by now'
#   '1' '3']
#  ['i often feel confused as to whether i have sin or just a really hard core sinful nautre'
#   '2' '3']
#  ['i can feel the presusre even more so on my shoulders and im feeling slightly unsure of myself which leads to unhappy thoughts not usually like my optimistic self i must say'
#   '2' '4']
#  ['i giggle when i write this and shake my head ni humbling disbelief but in a way i feel somewhat relieved'
#   '2' '3']
#  ['i feel more violnet than ever right now' '2' '3']
#  ['i said before do feel free to contact me this is something i am interested i nfinding out more about'
#   '3' '5']
#  ['a surprise party was planned in advance and her face lit up with excitement as she enetred the room'
#   '3' '5']
#  ['i also feel lethargic. ' '4' '5']
#  ['im all cooped up and impatient an dannoyingly annoying' '4' '5']
#  ['i feel the loving presence ofm y parents daily even though they have both been presumed dead for almost years now'
#   '4' '5']
#  ['i have been feeling guilty recently that i did not know back then that the abuse was not my fault and that it did not hpapen because of who i was'
#   '4' '3']
#  ['the unexpected plot twsit in the finale caught the audience off guard leaving them in shock'
#   '4' '5']
#  ['i think we need a little romantic comedy in the relatoinship' '5' '3']
#  ["i can't stop feeling lonel ywhen i am alone and when i've got no friends"
#   '5' '0']
#  ['i could never feel loving toward someone wtihout them ever knowing it if i dont act like it'
#   '5' '2']
#  ['i remained unprotected evne while traveling alone' '5' '0']]
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:Incorrect ner sentences
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:[['i could change the emphasis and say i am Matt and i m noticing i m feeling impatient'
#   '3' '5']
#  ['i looked at Deborah this morning i named my left breast Deborah my right one is Deborah and i feel this weird mixture of anger and loss Deborah wrote less than a month after her diagnosis'
#   '4' '0']
#  ['i get people asking me what it feels like to be the most hated man in Tucson county said assessor Philip Roberts'
#   '0' '5']
#  ['i was still feeling weepy and strung out so Charlie treated me to ice cream and a movie a spiderman'
#   '0' '3']]
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:Incorrect Negative sentences
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:[["i couldn't change the emphasis and say i am stella and i m noticing i m feeling impatient"
#   '3' '5']
#  ["i don't get the impression that banjo was really feeling it but molly still prefers her beloved katy perry purrrr"
#   '2' '3']
#  ["i get people asking me what it feels like to be the most hated man in dallas county didn't say assessor steve helm"
#   '0' '5']
#  ['i was still not feeling weepy and strung out so maggie treated me to ice cream and a movie a href http www'
#   '0' '3']
#  ["i don't feel embarrassed that it got so bad" '0' '3']
#  ["i don't spend a lot of time feeling disappointed with myself for not doing a better job at attaining my goals"
#   '0' '3']
#  ["i also don't feel lethargic and again" '0' '5']
#  ["i haven't been feeling regretful recently that i did not know back then that the abuse was not my fault and that it did not happen because of who i was but because of who they were"
#   '0' '1']
#  ["i don't believe that feeling accepted in a non judgemental way can be healing"
#   '1' '2']
#  ["i don't feel benevolent enough to buy them some peanuts and other treats"
#   '1' '3']
#  ["i don't write this i giggle and shake my head in humbling shame but in a way i feel somewhat triumphant"
#   '1' '3']
#  ["i didn't say before do feel free to contact me this is something i am interested in finding out more about"
#   '1' '5']
#  ["i soon didn't realize that an initial attraction to an activity that feels playful is often followed by a desire to practice to perfect the talent that led to the original enjoyment"
#   '1' '2']
#  ["i don't get frustrated that unresolved issues from my past have had a severe negative effect on my behavior and feel he must be angry that i have not resolved them by now"
#   '3' '4']]
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:Incorrect Positive sentences
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:[['i can stop the anxiety i feel when i m alone when i ve got no distractions'
#   '0' '3']
#  ['i can explain why but i need to say please understand my feeling i have heart and im a heartless person'
#   '3' '2']
#  ['i know if this helps at all but writing all of this has made me feel somewhat regretful of ashamed of who i was and while i have more to share i just think i can right now'
#   '0' '4']
#  ['i do really believe because i walked through all the water stops in my first marathon and i actually think that walking is bad but dammit i was feeling stubborn and i wanted to get home and needed to be motivated by something'
#   '3' '1']
#  ['i want them to feel so pressured' '4' '3']
#  ['i want to i feel irritated' '3' '2']
#  ["i know about you but i'm feeling amp blessed" '1' '5']
#  ['i have a schedule or childhood friends and feel a little timid about just getting out there by myself'
#   '4' '0']
#  ["i feel betrayed coz the backstabber had no grounds for their accusation but i'm just amazed at some people's ability to do such things"
#   '5' '3']
#  ["i eat a good breakfast i feel more energetic throughout the whole day and feel that o'clock slump"
#   '1' '5']]
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:Robusness Accuracies...
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:Vocab
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:0.4
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:Robusness
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:0.16666666666666666
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:NER
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:0.2
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:negative
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:0.125
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:positive
# INFO:mteb.evaluation.evaluators.ClassificationEvaluator:0.0
# ERROR:mteb.evaluation.MTEB:Error while evaluating EmotionClassification: all the input array dimensions except for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 6000 and the array at index 1 has size 2000
# ERROR:mteb.evaluation.MTEB:Please check all the error logs at: error_logs.txt
# Traceback (most recent call last):
#   File "/Users/nidhichowdhry/Documents/GMU/CS 678/Project/instructor-embedding/evaluation/MTEB/examples/evaluate_model.py", line 55, in <module>
#     evaluation.run(model, output_folder=args.output_dir, eval_splits=[args.split],args=args,)
#   File "/Users/nidhichowdhry/Documents/GMU/CS 678/Project/instructor-embedding/evaluation/MTEB/mteb/evaluation/MTEB.py", line 267, in run
#     task_name = list(evaluation_results.keys())[0]
# IndexError: list index out of range
