# %%
# !pip3 install googletrans==3.1.0a0

# %%
#!pip install googletrans==4.0.0-rc1
import googletrans
from googletrans import Translator
import pandas as pd
import time

import json

data = {}
data['key'] = 'value'
json_data = json.dumps(data)


# see available languages with the below
print(googletrans.LANGUAGES)
# Init
translator = Translator()
#Load PDF
df = pd.read_json('train_cache/medi_wiki.json')
queries = df['query'].values
positives = df.pos.values
negatives = df.neg.values
tasks = df.task_name.values
#print(texts)
for i, (query,pos,neg,task) in enumerate(zip(queries,positives,negatives,tasks)):
    query_translation = translator.translate(query[1], src='en', dest='hi')
    pos_translation = translator.translate(pos[1], src='en', dest='hi')
    neg_translation = translator.translate(neg[1], src='en', dest='hi')
    time.sleep(1)
    queries[i][1] = query_translation.text
    positives[i][1] = pos_translation.text
    negatives[i][1] = neg_translation.text
    

df.to_json(r'medi_wiki_hindi.json',orient="records",force_ascii=False,indent=4)


df = pd.read_json('train_cache/medi_wiki.json')
queries = df['query'].values
positives = df.pos.values
negatives = df.neg.values
tasks = df.task_name.values
#print(texts)
for i, (query,pos,neg,task) in enumerate(zip(queries,positives,negatives,tasks)):
    query_translation = translator.translate(query[1], src='en', dest='es')
    pos_translation = translator.translate(pos[1], src='en', dest='es')
    neg_translation = translator.translate(neg[1], src='en', dest='es')
    time.sleep(1)
    queries[i][1] = query_translation.text
    positives[i][1] = pos_translation.text
    negatives[i][1] = neg_translation.text
    
df.to_json(r'medi_wiki_spanish.json',orient="records",force_ascii=False,indent=4)

df = pd.read_json('train_cache/medi_wiki.json')
queries = df['query'].values
positives = df.pos.values
negatives = df.neg.values
tasks = df.task_name.values
#print(texts)
for i, (query,pos,neg,task) in enumerate(zip(queries,positives,negatives,tasks)):
    query_translation = translator.translate(query[1], src='en', dest='de')
    pos_translation = translator.translate(pos[1], src='en', dest='de')
    neg_translation = translator.translate(neg[1], src='en', dest='de')
    time.sleep(1)
    queries[i][1] = query_translation.text
    positives[i][1] = pos_translation.text
    negatives[i][1] = neg_translation.text
  
df.to_json(r'medi_wiki_german.json',orient="records",force_ascii=False,indent=4)


df = pd.read_json('train_cache/medi_wiki.json')
queries = df['query'].values
positives = df.pos.values
negatives = df.neg.values
tasks = df.task_name.values
#print(texts)
for i, (query,pos,neg,task) in enumerate(zip(queries,positives,negatives,tasks)):
    query_translation = translator.translate(query[1], src='en', dest='fr')
    pos_translation = translator.translate(pos[1], src='en', dest='fr')
    neg_translation = translator.translate(neg[1], src='en', dest='fr')
    time.sleep(1)
    queries[i][1] = query_translation.text
    positives[i][1] = pos_translation.text
    negatives[i][1] = neg_translation.text
  
df.to_json(r'medi_wiki_french.json',orient="records",force_ascii=False,indent=4)

df = pd.read_json('train_cache/medi_wiki.json')
queries = df['query'].values
positives = df.pos.values
negatives = df.neg.values
tasks = df.task_name.values
#print(texts)
for i, (query,pos,neg,task) in enumerate(zip(queries,positives,negatives,tasks)):
    query_translation = translator.translate(query[1], src='en', dest='th')
    pos_translation = translator.translate(pos[1], src='en', dest='th')
    neg_translation = translator.translate(neg[1], src='en', dest='th')
    time.sleep(1)
    queries[i][1] = query_translation.text
    positives[i][1] = pos_translation.text
    negatives[i][1] = neg_translation.text
  
df.to_json(r'medi_wiki_thai.json',orient="records",force_ascii=False,indent=4)

df = pd.read_json('medi_wiki_french.json')
queries = df['query'].values
positives = df.pos.values
negatives = df.neg.values
tasks = df.task_name.values
#print(texts)
for i, (query,pos,neg,task) in enumerate(zip(queries,positives,negatives,tasks)):
    query_translation = translator.translate(query[1], src='fr', dest='en')
    pos_translation = translator.translate(pos[1], src='fr', dest='en')
    neg_translation = translator.translate(neg[1], src='fr', dest='en')
    time.sleep(1)
    queries[i][1] = query_translation.text
    positives[i][1] = pos_translation.text
    negatives[i][1] = neg_translation.text
  
df.to_json(r'medi_wiki_english.json',orient="records",force_ascii=False,indent=4)

# %%
from datasets import load_dataset
import googletrans
from googletrans import Translator
import pandas as pd
import time

dataset = load_dataset("mteb/emotion",split='test')
print(dataset)

# translator = Translator()

# for i,data in enumerate(dataset):
#     translation = translator.translate(data['text'], src='en', dest='de')
#     dataset[i]['text']=translation.text
#     print(translation.text)
#     print(dataset[i]['text'] )
#     time.sleep(1)
#     if i>2:
#         break

df = pd.DataFrame(dataset, columns=['id', 'text','label', 'label_text'])

df.to_json(r'emotion.json',orient="records",force_ascii=False,indent=4)
# print(dataset[0])
# Out:
# Dataset({
#     features: ['text', 'label', 'label_text'],
#     num_rows: 2000
# })

# %%
import googletrans
from googletrans import Translator
import pandas as pd
import time

import json

data = {}
data['key'] = 'value'
json_data = json.dumps(data)


# see available languages with the below
print(googletrans.LANGUAGES)
# Init
translator = Translator()

df = pd.read_json('mtop_domain.json')

# print(df)
texts = df.text.values
labels = df.label.values

for i, (text,label) in enumerate(zip(texts,labels)):
    translation = translator.translate(text, src='en', dest='hi')
    time.sleep(1)
    texts[i] = translation.text
    print(texts[i])
    if i>2:
        break
   
  
df.to_json(r'mtop_domain_hi.json',orient="records",force_ascii=False,indent=4)



df = pd.read_json('mtop_domain.json')

# print(df)
texts = df.text.values
labels = df.label.values

for i, (text,label) in enumerate(zip(texts,labels)):
    translation = translator.translate(text, src='en', dest='de')
    time.sleep(1)
    texts[i] = translation.text
    print(texts[i])
    if i>2:
        break
   
  
df.to_json(r'mtop_domain_de.json',orient="records",force_ascii=False,indent=4)


df = pd.read_json('mtop_domain.json')

# print(df)
texts = df.text.values
labels = df.label.values

for i, (text,label) in enumerate(zip(texts,labels)):
    translation = translator.translate(text, src='en', dest='es')
    time.sleep(1)
    texts[i] = translation.text
    print(texts[i])
    if i>2:
        break
   
  
df.to_json(r'mtop_domain_es.json',orient="records",force_ascii=False,indent=4)



df = pd.read_json('mtop_domain.json')

# print(df)
texts = df.text.values
labels = df.label.values

for i, (text,label) in enumerate(zip(texts,labels)):
    translation = translator.translate(text, src='en', dest='fr')
    time.sleep(1)
    texts[i] = translation.text
    print(texts[i])
    if i>2:
        break
   
  
df.to_json(r'mtop_domain_fr.json',orient="records",force_ascii=False,indent=4)



df = pd.read_json('mtop_domain.json')

# print(df)
texts = df.text.values
labels = df.label.values

for i, (text,label) in enumerate(zip(texts,labels)):
    translation = translator.translate(text, src='en', dest='th')
    time.sleep(1)
    texts[i] = translation.text
    print(texts[i])
    if i>2:
        break
   
  
df.to_json(r'mtop_domain_th.json',orient="records",force_ascii=False,indent=4)


#greek
df = pd.read_json('mtop_domain.json')

# print(df)
texts = df.text.values
labels = df.label.values

for i, (text,label) in enumerate(zip(texts,labels)):
    translation = translator.translate(text, src='en', dest='el')
    time.sleep(1)
    texts[i] = translation.text
    print(texts[i])
    if i>2:
        break
   
  
df.to_json(r'mtop_domain_el.json',orient="records",force_ascii=False,indent=4)


df = pd.read_json('mtop_domain.json')

# print(df)
texts = df.text.values
labels = df.label.values

for i, (text,label) in enumerate(zip(texts,labels)):
    translation = translator.translate(text, src='en', dest='sw')
    time.sleep(1)
    texts[i] = translation.text
    print(texts[i])
    if i>2:
        break
   
  
df.to_json(r'mtop_domain_sw.json',orient="records",force_ascii=False,indent=4)
# Out:
# {'af': 'afrikaans', 'sq': 'albanian', 'am': 'amharic', 'ar': 'arabic', 'hy': 'armenian', 'az': 'azerbaijani', 'eu': 'basque', 'be': 'belarusian', 'bn': 'bengali', 'bs': 'bosnian', 'bg': 'bulgarian', 'ca': 'catalan', 'ceb': 'cebuano', 'ny': 'chichewa', 'zh-cn': 'chinese (simplified)', 'zh-tw': 'chinese (traditional)', 'co': 'corsican', 'hr': 'croatian', 'cs': 'czech', 'da': 'danish', 'nl': 'dutch', 'en': 'english', 'eo': 'esperanto', 'et': 'estonian', 'tl': 'filipino', 'fi': 'finnish', 'fr': 'french', 'fy': 'frisian', 'gl': 'galician', 'ka': 'georgian', 'de': 'german', 'el': 'greek', 'gu': 'gujarati', 'ht': 'haitian creole', 'ha': 'hausa', 'haw': 'hawaiian', 'iw': 'hebrew', 'he': 'hebrew', 'hi': 'hindi', 'hmn': 'hmong', 'hu': 'hungarian', 'is': 'icelandic', 'ig': 'igbo', 'id': 'indonesian', 'ga': 'irish', 'it': 'italian', 'ja': 'japanese', 'jw': 'javanese', 'kn': 'kannada', 'kk': 'kazakh', 'km': 'khmer', 'ko': 'korean', 'ku': 'kurdish (kurmanji)', 'ky': 'kyrgyz', 'lo': 'lao', 'la': 'l
# ...

# %%
import googletrans
from googletrans import Translator
import pandas as pd
import time

import json

data = {}
data['key'] = 'value'
json_data = json.dumps(data)


# see available languages with the below
print(googletrans.LANGUAGES)
# Init
translator = Translator()

df = pd.read_json('emotion.json')

# print(df)
texts = df.text.values
labels = df.label.values

for i, (text,label) in enumerate(zip(texts,labels)):
    translation = translator.translate(text, src='en', dest='hi')
    time.sleep(1)
    texts[i] = translation.text
    print(texts[i])
    if i>2:
        break
   
  
df.to_json(r'emotion_hi.json',orient="records",force_ascii=False,indent=4)



df = pd.read_json('emotion.json')

# print(df)
texts = df.text.values
labels = df.label.values

for i, (text,label) in enumerate(zip(texts,labels)):
    translation = translator.translate(text, src='en', dest='de')
    time.sleep(1)
    texts[i] = translation.text
    print(texts[i])
    if i>2:
        break   
   
  
df.to_json(r'emotion_de.json',orient="records",force_ascii=False,indent=4)


df = pd.read_json('emotion.json')

# print(df)
texts = df.text.values
labels = df.label.values

for i, (text,label) in enumerate(zip(texts,labels)):
    translation = translator.translate(text, src='en', dest='es')
    time.sleep(1)
    texts[i] = translation.text
    print(texts[i])
    if i>2:
        break 
   
  
df.to_json(r'emotion_es.json',orient="records",force_ascii=False,indent=4)



df = pd.read_json('emotion.json')

# print(df)
texts = df.text.values
labels = df.label.values

for i, (text,label) in enumerate(zip(texts,labels)):
    translation = translator.translate(text, src='en', dest='fr')
    time.sleep(1)
    texts[i] = translation.text
    print(texts[i])
    if i>2:
        break
   
  
df.to_json(r'emotion_fr.json',orient="records",force_ascii=False,indent=4)



df = pd.read_json('emotion.json')

# print(df)
texts = df.text.values
labels = df.label.values

for i, (text,label) in enumerate(zip(texts,labels)):
    translation = translator.translate(text, src='en', dest='th')
    time.sleep(1)
    texts[i] = translation.text
    print(texts[i])
    if i>2:
        break
   
  
df.to_json(r'emotion_th.json',orient="records",force_ascii=False,indent=4)


#greek
df = pd.read_json('emotion.json')

# print(df)
texts = df.text.values
labels = df.label.values

for i, (text,label) in enumerate(zip(texts,labels)):
    translation = translator.translate(text, src='en', dest='el')
    time.sleep(1)
    texts[i] = translation.text
    print(texts[i])
    if i>2:
        break
   
  
df.to_json(r'emotion_el.json',orient="records",force_ascii=False,indent=4)


df = pd.read_json('emotion.json')

# print(df)
texts = df.text.values
labels = df.label.values

for i, (text,label) in enumerate(zip(texts,labels)):
    translation = translator.translate(text, src='en', dest='sw')
    time.sleep(1)
    texts[i] = translation.text
    print(texts[i])
    if i>2:
        break
   
  
df.to_json(r'emotion_sw.json',orient="records",force_ascii=False,indent=4)
# Out:
# {'af': 'afrikaans', 'sq': 'albanian', 'am': 'amharic', 'ar': 'arabic', 'hy': 'armenian', 'az': 'azerbaijani', 'eu': 'basque', 'be': 'belarusian', 'bn': 'bengali', 'bs': 'bosnian', 'bg': 'bulgarian', 'ca': 'catalan', 'ceb': 'cebuano', 'ny': 'chichewa', 'zh-cn': 'chinese (simplified)', 'zh-tw': 'chinese (traditional)', 'co': 'corsican', 'hr': 'croatian', 'cs': 'czech', 'da': 'danish', 'nl': 'dutch', 'en': 'english', 'eo': 'esperanto', 'et': 'estonian', 'tl': 'filipino', 'fi': 'finnish', 'fr': 'french', 'fy': 'frisian', 'gl': 'galician', 'ka': 'georgian', 'de': 'german', 'el': 'greek', 'gu': 'gujarati', 'ht': 'haitian creole', 'ha': 'hausa', 'haw': 'hawaiian', 'iw': 'hebrew', 'he': 'hebrew', 'hi': 'hindi', 'hmn': 'hmong', 'hu': 'hungarian', 'is': 'icelandic', 'ig': 'igbo', 'id': 'indonesian', 'ga': 'irish', 'it': 'italian', 'ja': 'japanese', 'jw': 'javanese', 'kn': 'kannada', 'kk': 'kazakh', 'km': 'khmer', 'ko': 'korean', 'ku': 'kurdish (kurmanji)', 'ky': 'kyrgyz', 'lo': 'lao', 'la': 'l
# ...

# %%
import googletrans
from googletrans import Translator
import pandas as pd
import time

import json

data = {}
data['key'] = 'value'
json_data = json.dumps(data)


# see available languages with the below
print(googletrans.LANGUAGES)
# Init
translator = Translator()


#greek
df = pd.read_json('emotion.json')

# print(df)
texts = df.text.values
labels = df.label.values

for i, (text,label) in enumerate(zip(texts,labels)):
    translation = translator.translate(text, src='en', dest='el')
    time.sleep(1)
    texts[i] = translation.text
    print(texts[i])
   
   
  
df.to_json(r'emotion_el.json',orient="records",force_ascii=False,indent=4)


df = pd.read_json('emotion.json')

# print(df)
texts = df.text.values
labels = df.label.values

for i, (text,label) in enumerate(zip(texts,labels)):
    translation = translator.translate(text, src='en', dest='sw')
    time.sleep(1)
    texts[i] = translation.text
    print(texts[i])
   
   
  
df.to_json(r'emotion_sw.json',orient="records",force_ascii=False,indent=4)
# Out:
# {'af': 'afrikaans', 'sq': 'albanian', 'am': 'amharic', 'ar': 'arabic', 'hy': 'armenian', 'az': 'azerbaijani', 'eu': 'basque', 'be': 'belarusian', 'bn': 'bengali', 'bs': 'bosnian', 'bg': 'bulgarian', 'ca': 'catalan', 'ceb': 'cebuano', 'ny': 'chichewa', 'zh-cn': 'chinese (simplified)', 'zh-tw': 'chinese (traditional)', 'co': 'corsican', 'hr': 'croatian', 'cs': 'czech', 'da': 'danish', 'nl': 'dutch', 'en': 'english', 'eo': 'esperanto', 'et': 'estonian', 'tl': 'filipino', 'fi': 'finnish', 'fr': 'french', 'fy': 'frisian', 'gl': 'galician', 'ka': 'georgian', 'de': 'german', 'el': 'greek', 'gu': 'gujarati', 'ht': 'haitian creole', 'ha': 'hausa', 'haw': 'hawaiian', 'iw': 'hebrew', 'he': 'hebrew', 'hi': 'hindi', 'hmn': 'hmong', 'hu': 'hungarian', 'is': 'icelandic', 'ig': 'igbo', 'id': 'indonesian', 'ga': 'irish', 'it': 'italian', 'ja': 'japanese', 'jw': 'javanese', 'kn': 'kannada', 'kk': 'kazakh', 'km': 'khmer', 'ko': 'korean', 'ku': 'kurdish (kurmanji)', 'ky': 'kyrgyz', 'lo': 'lao', 'la': 'l
# ...
