# %% [markdown]
# Reproduction of experiments for InstructOR Embeddings on classification of sentences available in the below 2 datasets:
#
# 1. [MTEB Emotion dataset](https://huggingface.co/datasets/mteb/emotion)
# 2. [MTEB MTOP Domain](https://huggingface.co/datasets/mteb/mtop_domain/viewer/en)
#
# Steps to run the experiment:
#
# Step 1: Update parameters in the code cell for [MTEB Emotion classification](https://colab.research.google.com/drive/1jD8kxqu5dSFMvpSsX0N9yTWN9r3e43VM#scrollTo=_XboV6__tm5s&line=1&uniqifier=1) and [MTEB MTOP Domain Classification](https://colab.research.google.com/drive/1jD8kxqu5dSFMvpSsX0N9yTWN9r3e43VM#scrollTo=EiASp0ia44ci&line=2&uniqifier=1).The following parameters can be adjusted:
#
#
# 1. Seed (seed)
# 2. Batch Size (batch_size)
# 3. Training Samples/label for logistic regression (samples_per_label)
# 4. Number of Experiments per dataset (n_experiment)
#
# Step 2: Run all

# %%
# !git clone https://github.com/chow12327/instructor-embedding.git

# %%
# !pip install -r requirements.txt
# Out:
# 224.34s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...

# %%
# !pip install InstructorEmbedding
# Out:
# 234.92s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...

# %%
# !pip3 install -e evaluation/MTEB
# Out:
# 353.96s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Obtaining file:///Users/nidhichowdhry/Documents/GMU/CS%20678/Project/instructor-embedding/evaluation/MTEB
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for mteb (pyproject.toml) ... done
#   Created wheel for mteb: filename=mteb-1.0.0-0.editable-py3-none-any.whl size=3238 sha256=a206c0443abc2acea30c523a3110535382c8d76da05380e6d2dea070588f2dbb
#   Stored in directory: /private/var/folders/bm/86z3zxzj6pd_h3lv65x8wv140000gn/T/pip-ephem-wheel-cache-5fxra2px/wheels/ed/2f/7f/d3144c01b2713bfa2f5097752d4dd1ae6125cd8a0c12ad85f0
# Successfully built mteb
# ...
#   Attempting uninstall: mteb
#     Found existing installation: mteb 1.0.0
#     Uninstalling mteb-1.0.0:
# ...

# %%
#provide multiple parameter values here.

models = ['sentence-transformers/use-cmlm-multilingual']
seeds = [38]
batchsizes = [32]
samplesperlabels = [8]

for model in models:
  for seed in seeds:
    for batch_size in batchsizes:
      for samplesperlabel in samplesperlabels:
        # !python3 evaluation/MTEB/examples/evaluate_model.py --model_name {model} --output_dir outputs --task_name 'EmotionClassification' --result_file results --batch_size {batch_size} --samples_per_label {samplesperlabel} --n_experiments 1 --seed {seed}
# Out:
# 859.07s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: sentence-transformers/use-cmlm-multilingual
# load INSTRUCTOR_Transformer
# Some weights of the model checkpoint at /Users/nidhichowdhry/.cache/torch/sentence_transformers/sentence-transformers_use-cmlm-multilingual/ were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
#provide multiple parameter values here.

models = ['sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2']
seeds = [38]
batchsizes = [32]
samplesperlabels = [8]

for model in models:
  for seed in seeds:
    for batch_size in batchsizes:
      for samplesperlabel in samplesperlabels:
        # !python3 evaluation/MTEB/examples/evaluate_model.py --model_name {model} --output_dir outputs --task_name 'EmotionClassification' --result_file results --batch_size {batch_size} --samples_per_label {samplesperlabel} --n_experiments 1 --seed {seed}
# Out:
# 1815.14s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
# ...
# load INSTRUCTOR_Transformer
# max_seq_length  512
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device: cpu
# INFO:mteb.evaluation.MTEB:
#
# ## Evaluating 1 tasks:
# ─────────────────────────────── Selected tasks  ────────────────────────────────
# Classification
#     - EmotionClassification, s2s
#
#
# INFO:mteb.evaluation.MTEB:
#
# ********************** Evaluating EmotionClassification **********************
# INFO:mteb.evaluation.MTEB:Loading dataset for EmotionClassification
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
#
# Task: EmotionClassification, split: test. Running...
# ...

# %%
#provide multiple parameter values here.

models = ['sentence-transformers/distiluse-base-multilingual-cased-v2']
seeds = [38]
batchsizes = [32]
samplesperlabels = [8]

for model in models:
  for seed in seeds:
    for batch_size in batchsizes:
      for samplesperlabel in samplesperlabels:
        # !python3 evaluation/MTEB/examples/evaluate_model.py --model_name {model} --output_dir outputs --task_name 'EmotionClassification' --result_file results --batch_size {batch_size} --samples_per_label {samplesperlabel} --n_experiments 1 --seed {seed}
# Out:
# 2644.12s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: sentence-transformers/distiluse-base-multilingual-cased-v2
# load INSTRUCTOR_Transformer
# max_seq_length  512
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device: cpu
# INFO:mteb.evaluation.MTEB:
#
# ## Evaluating 1 tasks:
# ─────────────────────────────── Selected tasks  ────────────────────────────────
# Classification
#     - EmotionClassification, s2s
#
#
# INFO:mteb.evaluation.MTEB:
#
# ********************** Evaluating EmotionClassification **********************
# INFO:mteb.evaluation.MTEB:Loading dataset for EmotionClassification
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
#
# Task: EmotionClassification, split: test. Running...
# ...

# %%
#provide multiple parameter values here.
models = ['sentence-transformers/use-cmlm-multilingual']
seeds = [38]
batchsizes = [32]
samplesperlabels = [8]

for model in models:
  for seed in seeds:
    for batch_size in batchsizes:
      for samplesperlabel in samplesperlabels:
        # !python3 evaluation/MTEB/examples/evaluate_model.py --model_name {model} --output_dir outputs --task_name 'MTOPDomainClassification' --result_file results --batch_size {batch_size} --samples_per_label {samplesperlabel} --n_experiments 1 --seed {seed}
# Out:
# 1153.10s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: sentence-transformers/use-cmlm-multilingual
# load INSTRUCTOR_Transformer
# Some weights of the model checkpoint at /Users/nidhichowdhry/.cache/torch/sentence_transformers/sentence-transformers_use-cmlm-multilingual/ were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
#provide multiple parameter values here.
models = ['sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2']
seeds = [38]
batchsizes = [32]
samplesperlabels = [8]

for model in models:
  for seed in seeds:
    for batch_size in batchsizes:
      for samplesperlabel in samplesperlabels:
        # !python3 evaluation/MTEB/examples/evaluate_model.py --model_name {model} --output_dir outputs --task_name 'MTOPDomainClassification' --result_file results --batch_size {batch_size} --samples_per_label {samplesperlabel} --n_experiments 1 --seed {seed}
# Out:
# 2108.42s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
# load INSTRUCTOR_Transformer
# max_seq_length  512
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device: cpu
# INFO:mteb.evaluation.MTEB:
#
# ## Evaluating 1 tasks:
# ─────────────────────────────── Selected tasks  ────────────────────────────────
# Classification
#     - MTOPDomainClassification, s2s, multilingual 1 langs
#
#
# INFO:mteb.evaluation.MTEB:
#
# ********************** Evaluating MTOPDomainClassification **********************
# INFO:mteb.evaluation.MTEB:Loading dataset for MTOPDomainClassification
#
# Task: MTOPDomainClassification, split: test, language: en. Running...
# INFO:mteb.abstasks.AbsTaskClassification:========== Experiment 1/1 ==========
# Seed set at evaluate_model level
# ...

# %%
#provide multiple parameter values here.
models = ['sentence-transformers/distiluse-base-multilingual-cased-v2']
seeds = [38]
batchsizes = [32]
samplesperlabels = [8]

for model in models:
  for seed in seeds:
    for batch_size in batchsizes:
      for samplesperlabel in samplesperlabels:
        # !python3 evaluation/MTEB/examples/evaluate_model.py --model_name {model} --output_dir outputs --task_name 'MTOPDomainClassification' --result_file results --batch_size {batch_size} --samples_per_label {samplesperlabel} --n_experiments 1 --seed {seed}
# Out:
# 2538.37s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: sentence-transformers/distiluse-base-multilingual-cased-v2
# ...
# load INSTRUCTOR_Transformer
# max_seq_length  512
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device: cpu
# INFO:mteb.evaluation.MTEB:
#
# ## Evaluating 1 tasks:
# ─────────────────────────────── Selected tasks  ────────────────────────────────
# Classification
#     - MTOPDomainClassification, s2s, multilingual 1 langs
#
#
# INFO:mteb.evaluation.MTEB:
#
# ********************** Evaluating MTOPDomainClassification **********************
# INFO:mteb.evaluation.MTEB:Loading dataset for MTOPDomainClassification
#
# Task: MTOPDomainClassification, split: test, language: en. Running...
# INFO:mteb.abstasks.AbsTaskClassification:========== Experiment 1/1 ==========
# Seed set at evaluate_model level
# use logRegClassificationEvaluator
# ...
